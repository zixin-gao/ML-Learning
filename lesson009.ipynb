# %%
import torch

a = torch.ones((2,5,4))
a.shape
# Out:
# torch.Size([2, 5, 4])

# %%
a.sum(axis=1, keepdim=True).shape
# Out:
# torch.Size([2, 1, 4])

# %%
a.sum(axis=1, keepdim=False).shape
# Out:
# torch.Size([2, 4])

# %%
A = a.sum(axis=[0,2])
A
# Out:
# tensor([8., 8., 8., 8., 8.])
