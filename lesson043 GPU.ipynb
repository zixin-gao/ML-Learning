# %%
import torch
from torch import nn

torch.device('cpu'), torch.cuda.device('cuda'), torch.cuda.device('cuda:1')
# Out:
# (device(type='cpu'),
#  <torch.cuda.device at 0x15e58398830>,
#  <torch.cuda.device at 0x15e5819b390>)

# %%
torch.cuda.device_count()
# Out:
# 1

# %% [markdown]
# **check where the tensor is**

# %%
x = torch.tensor([1, 2, 3])
x.device
# Out:
# device(type='cpu')

# %%
def try_gpu(i=0):
    if torch.cuda.device_count() >= i+1:
        return torch.device(f"cuda:{i}")
    return torch.device(cpu)

# %% [markdown]
# **put on GPU**

# %%
X = torch.ones(2, 3, device=try_gpu())
X
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')

# %%
Z = X.cuda(0)
print(X)
print(Z)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')

# %%
Y = torch.normal(0, 1, (2, 3), device="cuda:0")
Y = Y.cuda(0)
Y
# Out:
# tensor([[-0.5630,  0.8792, -0.0701],
#         [ 0.0538,  0.0491, -0.9515]], device='cuda:0')

# %%
Z + Y
# Out:
# tensor([[0.4370, 1.8792, 0.9299],
#         [1.0538, 1.0491, 0.0485]], device='cuda:0')

# %% [markdown]
# ### NN on GPU

# %%
net = nn.Sequential(nn.Linear(3, 1))
net = net.to(device=try_gpu())
net(X)
# everything is processed and stored on gpu
# Out:
# tensor([[0.2764],
#         [0.2764]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
net[0].weight.data.device
# Out:
# device(type='cuda', index=0)
